# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
arabica_df = pd.read_csv("Resources/arabica_data_cleaned.csv")
arabica_df
# Out:
#       Unnamed: 0  Species                       Owner Country.of.Origin  \
# 0              1  Arabica                   metad plc          Ethiopia
# 1              2  Arabica                   metad plc          Ethiopia
# 2              3  Arabica    grounds for health admin         Guatemala
# 3              4  Arabica         yidnekachew dabessa          Ethiopia
# 4              5  Arabica                   metad plc          Ethiopia
# ...          ...      ...                         ...               ...
# 1306        1307  Arabica    juan carlos garcia lopez            Mexico
# 1307        1308  Arabica     myriam kaplan-pasternak             Haiti
# 1308        1309  Arabica  exportadora atlantic, s.a.         Nicaragua
# 1309        1310  Arabica   juan luis alvarado romero         Guatemala
# 1310        1312  Arabica             bismarck castro          Honduras
#
#                                      Farm.Name                  Lot.Number  \
# ...

# %%
robusta_df = pd.read_csv("Resources/robusta_data_cleaned.csv")
robusta_df
# Out:
#     Unnamed: 0  Species                              Owner Country.of.Origin  \
# 0            1  Robusta       ankole coffee producers coop            Uganda
# 1            2  Robusta                     nishant gurjer             India
# 2            3  Robusta                      andrew hetzel             India
# 3            4  Robusta                             ugacof            Uganda
# 4            5  Robusta       katuka development trust ltd            Uganda
# 5            6  Robusta                      andrew hetzel             India
# 6            7  Robusta                      andrew hetzel             India
# 7            8  Robusta                     nishant gurjer             India
# 8            9  Robusta                     nishant gurjer             India
# 9           10  Robusta                             ugacof            Uganda
# 10          11  Robusta                             ugacof            Uganda
# ...

# %%
coffee_df = arabica_df.append(robusta_df, ignore_index=True)
coffee_df
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              1  Arabica                 metad plc          Ethiopia
# 1              2  Arabica                 metad plc          Ethiopia
# 2              3  Arabica  grounds for health admin         Guatemala
# 3              4  Arabica       yidnekachew dabessa          Ethiopia
# 4              5  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334          24  Robusta               luis robles           Ecuador
# 1335          25  Robusta               luis robles           Ecuador
# 1336          26  Robusta               james moore     United States
# 1337          27  Robusta             cafe politico             India
# 1338          28  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# ...
